# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenKumar-1808/Machine-Learning/blob/main/EM_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.mixture import GaussianMixture

# Student marks data
marks = np.array([85, 78, 82, 58, 62, 55, 79, 61]).reshape(-1, 1)

# EM model: 2 hidden groups
model = GaussianMixture(n_components=2, random_state=0)

# Train model
model.fit(marks)

# Predict group
groups = model.predict(marks)

print("Marks:", marks.ravel())
print("Predicted Groups:", groups)

print("\nGroup Means:")
print(model.means_)

print("\nGroup Probabilities:")
print(model.weights_)
# Out:
# Marks: [85 78 82 58 62 55 79 61]
# Predicted Groups: [1 1 1 0 0 0 1 0]
#
# Group Means:
# [[59.]
#  [81.]]
#
# Group Probabilities:
# [0.5 0.5]
